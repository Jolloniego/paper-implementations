# %% [markdown]
# Implementation of GAN training framework for MNIST dataset using CNN generator and discriminator.
# ##[Paper](https://arxiv.org/pdf/1406.2661.pdf)

# %%
import time
import torch
import torchvision
import numpy as np
from PIL import Image
import torch.nn as nn
import matplotlib.pyplot as plt 
import torch.nn.functional as F
from torchvision import transforms
from torchvision.datasets import MNIST
from sklearn.metrics import accuracy_score
from torch.utils.data.dataloader import DataLoader
from torchvision.utils import make_grid, save_image

# Fix random seed
torch.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

print(f"Using {device}")
# Out:
# Using cuda:0

# %%
train_images = MNIST("", train=True, transform=transforms.ToTensor(), download=True)  # 28x28 size

BATCH_SIZE = 32   # Size of minibatches
LATENT_DIM = 50 # Dimension size for the random noise Z
INITIAL_MAP_SIZE = 7   # Dimension size for the initial SxS images generated from the noise

# %%
### GENERATOR

class UpSampleConv(nn.Module):
  def __init__(self, in_channels, out_channels):
    super(UpSampleConv, self).__init__()
    self.up = nn.Upsample(scale_factor=2)
    self.batch_norm = nn.BatchNorm2d(out_channels)
    self.conv = nn.Conv2d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, padding=1)

  def forward(self, x):
    out = self.up(x)
    out = self.conv(out)
    out = self.batch_norm(out)
    out = F.relu(out)
    return out

class GenModel(nn.Module):
  def __init__(self, initial_channels=64, latent_dim=LATENT_DIM, initial_map=INITIAL_MAP_SIZE):
    super(GenModel, self).__init__()
    self.initial_map_size = initial_map
    self.initial_channels = initial_channels
    self.linear = nn.Linear(in_features=latent_dim, out_features=initial_channels * initial_map * initial_map)
    self.upsample = nn.Sequential(UpSampleConv(in_channels=initial_channels, out_channels=initial_channels), UpSampleConv(in_channels=initial_channels, out_channels=1))
  
  def forward(self, x):
    result = F.relu(self.linear(x))
    result = result.view(-1, self.initial_channels, self.initial_map_size, self.initial_map_size)

    result = self.upsample(result).squeeze(dim=1)
    
    return result


### DISCRIMINATOR

class DiscModel(nn.Module):
  def __init__(self, in_channels=1, out_classes=2):
    super(DiscModel, self).__init__()
    self.conv1 = nn.Conv2d(in_channels=in_channels, out_channels=16, kernel_size=3, padding=1)
    self.conv2 = nn.Conv2d(in_channels=16, out_channels=8, kernel_size=3, padding=1)
    self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
    self.output = nn.Linear(in_features=8 * 7 * 7, out_features=out_classes)
  
  def forward(self, x):
    out = self.conv1(x)
    out = F.leaky_relu(self.pool(out), 0.2)

    out = self.conv2(out)
    out = F.leaky_relu(self.pool(out), 0.2)

    out = out.flatten(1)

    return self.output(out)

# %%
def adversarial_train(generator, discriminator, gen_optim, disc_optim, data_loader, loss_function, latent_dim=LATENT_DIM, batch_size=BATCH_SIZE, epochs=50):
  real_label = torch.ones(batch_size).long().to(device)
  fake_label = torch.zeros(batch_size).long().to(device)
  
  evaluation_noise = torch.normal(mean=0, std=1, size=(batch_size, latent_dim)).to(device)

  gen_losses = []
  accuracies = []
  disc_fake_losses = []
  disc_valid_losses = []

  for current_epoch in range(epochs):
    start = time.time()

    gen_loss = 0
    disc_loss_valid = 0
    disc_loss_fake = 0
    all_predictions = []

    for real_images, _ in data_loader:
      # Train generator
      gen_optim.zero_grad()
      noise = torch.normal(mean=0, std=1, size=(batch_size, latent_dim)).to(device)
      gen_images = generator(noise)

      fake_data_predictions = discriminator(gen_images.unsqueeze(1))

      # Measure ability of generator to FOOL discriminator
      gen_cost = loss_function(fake_data_predictions, real_label)
      gen_cost.backward()
      gen_optim.step()

      all_predictions.extend(torch.argmax(fake_data_predictions, dim=1).cpu().numpy())

      # Train discriminator
      disc_optim.zero_grad()
      
      disc_real_cost = loss_function(discriminator(real_images.to(device)), real_label)
      disc_fake_cost = loss_function(discriminator(gen_images.unsqueeze(1).detach()), fake_label)

      disc_total_cost = disc_real_cost + disc_fake_cost
      disc_total_cost.backward()
      disc_optim.step()

      gen_loss += gen_cost.item()
      disc_loss_fake += disc_fake_cost.item()
      disc_loss_valid += disc_real_cost.item()
    
    gen_losses.append(gen_loss / len(data_loader))
    disc_fake_losses.append(disc_loss_fake / len(data_loader))
    disc_valid_losses.append(disc_loss_valid / len(data_loader))

    gen_images = generator(evaluation_noise)
    grid = make_grid(gen_images.unsqueeze(1))
    save_image(grid, f"sample_data/{current_epoch + 1}.png")

    disc_fake_accuracy = accuracy_score(np.zeros(len(all_predictions)), all_predictions)
    accuracies.append(disc_fake_accuracy)

    print(f"Epoch {current_epoch + 1} | "
          f"Accuracy {disc_fake_accuracy:.2f} | "
          f"Gen Loss {(gen_loss / len(data_loader)):.6f} | "
          f"Disc Fake Loss {(disc_loss_fake / len(data_loader)):.6f} | "
          f"Disc Valid Loss {(disc_loss_valid / len(data_loader)):.6f}| "
          f"Time {(time.time() - start):.2f} sec")

  return gen_losses, disc_fake_losses, disc_valid_losses, accuracies

# %%
train_dataloader = DataLoader(train_images, batch_size=BATCH_SIZE, num_workers=8, pin_memory=True)

generator = GenModel(latent_dim=LATENT_DIM).to(device)
discriminator = DiscModel(in_channels=1).to(device)

gen_optim = torch.optim.Adam(generator.parameters(), lr=0.0002)
disc_optim = torch.optim.Adam(discriminator.parameters(), lr=0.0002)

cost_function = nn.CrossEntropyLoss().to(device)

# %%
N_EPOCHS = 100

gen_losses, disc_fake_losses, disc_valid_losses, accuracies = adversarial_train(generator, discriminator, gen_optim, disc_optim, train_dataloader, cost_function, epochs=N_EPOCHS)

plt.plot(range(N_EPOCHS), gen_losses, label="Generator")
plt.plot(range(N_EPOCHS), disc_fake_losses, label="Disc. Fake")
plt.plot(range(N_EPOCHS), disc_valid_losses, label="Disc. Valid")
plt.legend()
plt.title("Cost functions")
plt.show()

plt.plot(range(N_EPOCHS), accuracies)
plt.title("Accuracy on fake data")
plt.show()
# Out:
# Epoch 1 | Accuracy 0.78 | Gen Loss 0.860133 | Disc Fake Loss 0.588851 | Disc Valid Loss 0.611030| Time 20.71 sec
# Epoch 2 | Accuracy 0.78 | Gen Loss 0.887252 | Disc Fake Loss 0.567647 | Disc Valid Loss 0.575702| Time 20.12 sec
# Epoch 3 | Accuracy 0.75 | Gen Loss 0.883320 | Disc Fake Loss 0.576282 | Disc Valid Loss 0.586335| Time 20.07 sec
# Epoch 4 | Accuracy 0.78 | Gen Loss 0.956084 | Disc Fake Loss 0.542177 | Disc Valid Loss 0.554858| Time 19.91 sec
# Epoch 5 | Accuracy 0.77 | Gen Loss 0.984675 | Disc Fake Loss 0.537261 | Disc Valid Loss 0.552493| Time 21.31 sec
# Epoch 6 | Accuracy 0.76 | Gen Loss 0.979631 | Disc Fake Loss 0.544011 | Disc Valid Loss 0.562951| Time 20.29 sec
# Epoch 7 | Accuracy 0.76 | Gen Loss 0.986963 | Disc Fake Loss 0.543973 | Disc Valid Loss 0.565281| Time 20.81 sec
# Epoch 8 | Accuracy 0.76 | Gen Loss 1.007838 | Disc Fake Loss 0.534192 | Disc Valid Loss 0.558378| Time 20.45 sec
# Epoch 9 | Accuracy 0.77 | Gen Loss 1.016361 | Disc Fake Loss 0.531326 | Disc Valid Loss 0.554334| Time 20.60 sec
# Epoch 10 | Accuracy 0.76 | Gen Loss 1.018052 | Disc Fake Loss 0.535355 | Disc Valid Loss 0.556821| Time 20.79 sec
# Epoch 11 | Accuracy 0.75 | Gen Loss 1.017481 | Disc Fake Loss 0.538591 | Disc Valid Loss 0.561735| Time 21.01 sec
# Epoch 12 | Accuracy 0.76 | Gen Loss 1.030876 | Disc Fake Loss 0.531862 | Disc Valid Loss 0.556034| Time 20.26 sec
# Epoch 13 | Accuracy 0.76 | Gen Loss 1.046472 | Disc Fake Loss 0.527475 | Disc Valid Loss 0.551031| Time 20.46 sec
# Epoch 14 | Accuracy 0.76 | Gen Loss 1.054933 | Disc Fake Loss 0.527711 | Disc Valid Loss 0.550473| Time 20.58 sec
# Epoch 15 | Accuracy 0.76 | Gen Loss 1.054642 | Disc Fake Loss 0.529099 | Disc Valid Loss 0.553036| Time 20.12 sec
# Epoch 16 | Accuracy 0.75 | Gen Loss 1.059078 | Disc Fake Loss 0.530725 | Disc Valid Loss 0.554908| Time 20.55 sec
# Epoch 17 | Accuracy 0.75 | Gen Loss 1.061106 | Disc Fake Loss 0.530489 | Disc Valid Loss 0.558349| Time 20.64 sec
# Epoch 18 | Accuracy 0.75 | Gen Loss 1.067006 | Disc Fake Loss 0.531099 | Disc Valid Loss 0.557953| Time 20.52 sec
# Epoch 19 | Accuracy 0.74 | Gen Loss 1.060470 | Disc Fake Loss 0.535024 | Disc Valid Loss 0.564033| Time 20.75 sec
# Epoch 20 | Accuracy 0.74 | Gen Loss 1.071095 | Disc Fake Loss 0.533774 | Disc Valid Loss 0.561051| Time 19.95 sec
# Epoch 21 | Accuracy 0.74 | Gen Loss 1.061023 | Disc Fake Loss 0.540428 | Disc Valid Loss 0.566971| Time 20.78 sec
# Epoch 22 | Accuracy 0.74 | Gen Loss 1.069945 | Disc Fake Loss 0.538720 | Disc Valid Loss 0.563486| Time 20.86 sec
# Epoch 23 | Accuracy 0.74 | Gen Loss 1.073467 | Disc Fake Loss 0.540823 | Disc Valid Loss 0.565159| Time 19.89 sec
# Epoch 24 | Accuracy 0.73 | Gen Loss 1.072093 | Disc Fake Loss 0.545449 | Disc Valid Loss 0.572245| Time 20.44 sec
# Epoch 25 | Accuracy 0.73 | Gen Loss 1.071386 | Disc Fake Loss 0.548196 | Disc Valid Loss 0.571177| Time 20.25 sec
# Epoch 26 | Accuracy 0.73 | Gen Loss 1.073661 | Disc Fake Loss 0.543499 | Disc Valid Loss 0.568627| Time 20.37 sec
# Epoch 27 | Accuracy 0.73 | Gen Loss 1.051830 | Disc Fake Loss 0.549065 | Disc Valid Loss 0.576769| Time 20.59 sec
# Epoch 28 | Accuracy 0.72 | Gen Loss 1.040864 | Disc Fake Loss 0.554103 | Disc Valid Loss 0.581681| Time 20.52 sec
# Epoch 29 | Accuracy 0.72 | Gen Loss 1.026234 | Disc Fake Loss 0.562215 | Disc Valid Loss 0.588995| Time 19.94 sec
# Epoch 30 | Accuracy 0.71 | Gen Loss 1.022537 | Disc Fake Loss 0.567366 | Disc Valid Loss 0.592428| Time 20.53 sec
# Epoch 31 | Accuracy 0.71 | Gen Loss 1.017431 | Disc Fake Loss 0.570524 | Disc Valid Loss 0.595273| Time 20.47 sec
# Epoch 32 | Accuracy 0.71 | Gen Loss 1.014330 | Disc Fake Loss 0.567206 | Disc Valid Loss 0.593864| Time 20.74 sec
# Epoch 33 | Accuracy 0.72 | Gen Loss 1.018340 | Disc Fake Loss 0.562732 | Disc Valid Loss 0.590115| Time 20.43 sec
# Epoch 34 | Accuracy 0.71 | Gen Loss 1.015381 | Disc Fake Loss 0.563790 | Disc Valid Loss 0.590752| Time 20.59 sec
# Epoch 35 | Accuracy 0.72 | Gen Loss 1.022999 | Disc Fake Loss 0.563450 | Disc Valid Loss 0.590707| Time 20.01 sec
# Epoch 36 | Accuracy 0.71 | Gen Loss 1.020592 | Disc Fake Loss 0.565177 | Disc Valid Loss 0.592423| Time 19.94 sec
# Epoch 37 | Accuracy 0.71 | Gen Loss 1.015507 | Disc Fake Loss 0.565772 | Disc Valid Loss 0.596542| Time 20.31 sec
# Epoch 38 | Accuracy 0.71 | Gen Loss 1.010855 | Disc Fake Loss 0.571730 | Disc Valid Loss 0.599916| Time 20.66 sec
# Epoch 39 | Accuracy 0.70 | Gen Loss 1.014882 | Disc Fake Loss 0.573069 | Disc Valid Loss 0.602947| Time 20.51 sec
# Epoch 40 | Accuracy 0.70 | Gen Loss 1.017438 | Disc Fake Loss 0.576271 | Disc Valid Loss 0.604952| Time 20.45 sec
# Epoch 41 | Accuracy 0.70 | Gen Loss 1.020317 | Disc Fake Loss 0.573580 | Disc Valid Loss 0.604068| Time 20.21 sec
# Epoch 42 | Accuracy 0.70 | Gen Loss 1.014661 | Disc Fake Loss 0.572353 | Disc Valid Loss 0.601262| Time 20.08 sec
# Epoch 43 | Accuracy 0.71 | Gen Loss 1.011935 | Disc Fake Loss 0.570872 | Disc Valid Loss 0.599611| Time 20.16 sec
# Epoch 44 | Accuracy 0.71 | Gen Loss 1.011984 | Disc Fake Loss 0.571298 | Disc Valid Loss 0.600049| Time 19.80 sec
# Epoch 45 | Accuracy 0.71 | Gen Loss 1.019761 | Disc Fake Loss 0.565988 | Disc Valid Loss 0.598354| Time 20.21 sec
# Epoch 46 | Accuracy 0.71 | Gen Loss 1.013506 | Disc Fake Loss 0.569372 | Disc Valid Loss 0.598438| Time 20.41 sec
# Epoch 47 | Accuracy 0.71 | Gen Loss 1.003903 | Disc Fake Loss 0.573800 | Disc Valid Loss 0.606024| Time 20.22 sec
# Epoch 48 | Accuracy 0.71 | Gen Loss 1.006185 | Disc Fake Loss 0.571723 | Disc Valid Loss 0.604779| Time 20.29 sec
# Epoch 49 | Accuracy 0.71 | Gen Loss 1.003997 | Disc Fake Loss 0.573023 | Disc Valid Loss 0.605290| Time 19.93 sec
# Epoch 50 | Accuracy 0.71 | Gen Loss 1.009468 | Disc Fake Loss 0.572644 | Disc Valid Loss 0.605222| Time 19.86 sec
# Epoch 51 | Accuracy 0.70 | Gen Loss 1.003343 | Disc Fake Loss 0.574837 | Disc Valid Loss 0.606499| Time 20.33 sec
# Epoch 52 | Accuracy 0.71 | Gen Loss 1.000084 | Disc Fake Loss 0.576548 | Disc Valid Loss 0.607414| Time 20.93 sec
# Epoch 53 | Accuracy 0.71 | Gen Loss 1.013467 | Disc Fake Loss 0.571822 | Disc Valid Loss 0.601877| Time 21.31 sec
# Epoch 54 | Accuracy 0.70 | Gen Loss 1.003974 | Disc Fake Loss 0.576658 | Disc Valid Loss 0.606810| Time 21.01 sec
# Epoch 55 | Accuracy 0.71 | Gen Loss 1.009519 | Disc Fake Loss 0.571177 | Disc Valid Loss 0.602579| Time 20.74 sec
# Epoch 56 | Accuracy 0.71 | Gen Loss 1.002790 | Disc Fake Loss 0.573404 | Disc Valid Loss 0.605281| Time 20.18 sec
# Epoch 57 | Accuracy 0.70 | Gen Loss 1.003396 | Disc Fake Loss 0.575212 | Disc Valid Loss 0.608522| Time 20.24 sec
# Epoch 58 | Accuracy 0.70 | Gen Loss 0.995190 | Disc Fake Loss 0.578114 | Disc Valid Loss 0.610691| Time 20.29 sec
# Epoch 59 | Accuracy 0.70 | Gen Loss 0.993171 | Disc Fake Loss 0.578426 | Disc Valid Loss 0.610187| Time 20.71 sec
# Epoch 60 | Accuracy 0.71 | Gen Loss 0.999220 | Disc Fake Loss 0.575339 | Disc Valid Loss 0.608136| Time 20.48 sec
# Epoch 61 | Accuracy 0.71 | Gen Loss 1.005646 | Disc Fake Loss 0.571437 | Disc Valid Loss 0.603413| Time 20.88 sec
# Epoch 62 | Accuracy 0.71 | Gen Loss 0.999047 | Disc Fake Loss 0.574570 | Disc Valid Loss 0.606173| Time 20.19 sec
# Epoch 63 | Accuracy 0.71 | Gen Loss 1.003238 | Disc Fake Loss 0.572801 | Disc Valid Loss 0.602889| Time 20.16 sec
# Epoch 64 | Accuracy 0.70 | Gen Loss 0.995762 | Disc Fake Loss 0.577910 | Disc Valid Loss 0.608646| Time 20.30 sec
# Epoch 65 | Accuracy 0.70 | Gen Loss 0.994529 | Disc Fake Loss 0.579791 | Disc Valid Loss 0.608934| Time 20.39 sec
# Epoch 66 | Accuracy 0.69 | Gen Loss 0.989403 | Disc Fake Loss 0.582916 | Disc Valid Loss 0.609939| Time 19.98 sec
# Epoch 67 | Accuracy 0.70 | Gen Loss 0.986554 | Disc Fake Loss 0.582622 | Disc Valid Loss 0.610688| Time 20.09 sec
# Epoch 68 | Accuracy 0.70 | Gen Loss 0.989825 | Disc Fake Loss 0.579192 | Disc Valid Loss 0.607990| Time 21.61 sec
# Epoch 69 | Accuracy 0.70 | Gen Loss 0.992538 | Disc Fake Loss 0.577095 | Disc Valid Loss 0.606527| Time 20.56 sec
# Epoch 70 | Accuracy 0.71 | Gen Loss 1.000629 | Disc Fake Loss 0.572790 | Disc Valid Loss 0.601622| Time 20.53 sec
# Epoch 71 | Accuracy 0.70 | Gen Loss 1.000197 | Disc Fake Loss 0.575165 | Disc Valid Loss 0.604517| Time 21.27 sec
# Epoch 72 | Accuracy 0.71 | Gen Loss 0.998239 | Disc Fake Loss 0.573176 | Disc Valid Loss 0.601695| Time 19.97 sec
# Epoch 73 | Accuracy 0.70 | Gen Loss 0.988918 | Disc Fake Loss 0.577147 | Disc Valid Loss 0.605801| Time 19.72 sec
# Epoch 74 | Accuracy 0.70 | Gen Loss 0.982055 | Disc Fake Loss 0.579488 | Disc Valid Loss 0.608900| Time 20.73 sec
# Epoch 75 | Accuracy 0.70 | Gen Loss 0.983618 | Disc Fake Loss 0.578667 | Disc Valid Loss 0.607947| Time 19.80 sec
# Epoch 76 | Accuracy 0.70 | Gen Loss 0.972522 | Disc Fake Loss 0.583243 | Disc Valid Loss 0.613759| Time 20.35 sec
# Epoch 77 | Accuracy 0.71 | Gen Loss 0.990140 | Disc Fake Loss 0.575091 | Disc Valid Loss 0.606777| Time 20.14 sec
# Epoch 78 | Accuracy 0.70 | Gen Loss 0.987765 | Disc Fake Loss 0.577462 | Disc Valid Loss 0.606754| Time 20.23 sec
# Epoch 79 | Accuracy 0.70 | Gen Loss 0.982694 | Disc Fake Loss 0.580320 | Disc Valid Loss 0.610248| Time 20.72 sec
# Epoch 80 | Accuracy 0.70 | Gen Loss 0.977081 | Disc Fake Loss 0.583083 | Disc Valid Loss 0.610475| Time 20.23 sec
# Epoch 81 | Accuracy 0.70 | Gen Loss 0.986154 | Disc Fake Loss 0.577864 | Disc Valid Loss 0.606722| Time 21.11 sec
# Epoch 82 | Accuracy 0.70 | Gen Loss 0.989120 | Disc Fake Loss 0.578045 | Disc Valid Loss 0.605349| Time 20.61 sec
# Epoch 83 | Accuracy 0.71 | Gen Loss 0.993340 | Disc Fake Loss 0.577630 | Disc Valid Loss 0.606319| Time 20.27 sec
# Epoch 84 | Accuracy 0.70 | Gen Loss 0.995341 | Disc Fake Loss 0.578586 | Disc Valid Loss 0.606900| Time 20.41 sec
# Epoch 85 | Accuracy 0.70 | Gen Loss 0.994183 | Disc Fake Loss 0.576790 | Disc Valid Loss 0.604787| Time 20.45 sec
# Epoch 86 | Accuracy 0.70 | Gen Loss 0.983201 | Disc Fake Loss 0.582176 | Disc Valid Loss 0.610495| Time 20.81 sec
# Epoch 87 | Accuracy 0.70 | Gen Loss 0.984178 | Disc Fake Loss 0.583039 | Disc Valid Loss 0.608212| Time 19.79 sec
# Epoch 88 | Accuracy 0.70 | Gen Loss 0.983169 | Disc Fake Loss 0.582797 | Disc Valid Loss 0.608427| Time 20.44 sec
# Epoch 89 | Accuracy 0.70 | Gen Loss 0.986948 | Disc Fake Loss 0.577654 | Disc Valid Loss 0.603895| Time 20.60 sec
# Epoch 90 | Accuracy 0.70 | Gen Loss 0.987044 | Disc Fake Loss 0.578687 | Disc Valid Loss 0.604395| Time 20.60 sec
# Epoch 91 | Accuracy 0.70 | Gen Loss 0.973362 | Disc Fake Loss 0.584597 | Disc Valid Loss 0.611019| Time 20.30 sec
# Epoch 92 | Accuracy 0.70 | Gen Loss 0.970750 | Disc Fake Loss 0.583950 | Disc Valid Loss 0.610463| Time 19.78 sec
# Epoch 93 | Accuracy 0.70 | Gen Loss 0.963178 | Disc Fake Loss 0.587324 | Disc Valid Loss 0.611127| Time 21.09 sec
# Epoch 94 | Accuracy 0.70 | Gen Loss 0.976002 | Disc Fake Loss 0.582404 | Disc Valid Loss 0.606837| Time 20.58 sec
# Epoch 95 | Accuracy 0.70 | Gen Loss 0.978123 | Disc Fake Loss 0.580584 | Disc Valid Loss 0.606057| Time 20.04 sec
# Epoch 96 | Accuracy 0.70 | Gen Loss 0.985581 | Disc Fake Loss 0.579524 | Disc Valid Loss 0.605216| Time 20.27 sec
# Epoch 97 | Accuracy 0.70 | Gen Loss 0.984446 | Disc Fake Loss 0.577144 | Disc Valid Loss 0.606451| Time 19.70 sec
# Epoch 98 | Accuracy 0.71 | Gen Loss 0.992156 | Disc Fake Loss 0.573179 | Disc Valid Loss 0.603271| Time 20.23 sec
# Epoch 99 | Accuracy 0.71 | Gen Loss 1.015652 | Disc Fake Loss 0.568323 | Disc Valid Loss 0.594547| Time 20.46 sec
# Epoch 100 | Accuracy 0.71 | Gen Loss 1.003049 | Disc Fake Loss 0.570574 | Disc Valid Loss 0.598428| Time 20.95 sec

# %%
image = Image.open('sample_data/1.png')
plt.imshow(image)
plt.title("Results after 1 epochs")
plt.axis('off')
plt.show()

image = Image.open('sample_data/20.png')
plt.imshow(image)
plt.title("Results after 20 epochs")
plt.axis('off')
plt.show()

image = Image.open('sample_data/50.png')
plt.imshow(image)
plt.title("Results after 50 epochs")
plt.axis('off')
plt.show()

image = Image.open('sample_data/100.png')
plt.imshow(image)
plt.title("Results after 100 epochs")
plt.axis('off')
plt.show()
